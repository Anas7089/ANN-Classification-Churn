# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
import pickle
# land of bad tr.ailer hindi

# %%
# load the trained model, scaler pickle file, and one hot encoder pickle file
model = load_model('model.h5')

# load he encoder and scaler
with open('one_hot_encoder_geo.pkl', 'rb') as file:
    one_hot_encoder_geo = pickle.load(file)

with open('scaler.pkl', 'rb') as file:
    scaler = pickle.load(file)

with open('label_encoder_gender.pkl', 'rb') as file:
    label_encoder_gender = pickle.load(file)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# examole new data point
new_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
# one hot encode 'Geography'
geo_encoded = one_hot_encoder_geo.transform([[new_data['Geography']]]).toarray()
geo_encoded_df = pd.DataFrame(geo_encoded, columns=one_hot_encoder_geo.get_feature_names_out(['Geography']))
# Out:
# c:\Users\shaik\.conda\envs\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
geo_encoded_df
# Out:
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
new_df = pd.DataFrame([new_data])
new_df
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
# Encode categorical variables
new_df['Gender'] = label_encoder_gender.transform(new_df['Gender'])
new_df
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France       1   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
# concanation one hot encoded
input_df = pd.concat([new_df.drop('Geography', axis=1), geo_encoded_df], axis=1)

# %%
# combine the one hot encoded columns with the original data
input_data = pd.concat([new_df.drop('Geography', axis=1), geo_encoded_df], axis=1)
